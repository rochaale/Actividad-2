# %% [markdown]
# Duración de una playlist

# %% [markdown]
# Dada la siguiente playlist con canciones y sus duraciones en formato "m:ss":

# %%
playlist = [
{"title": "Bohemian Rhapsody", "duration": "5:55"},
{"title": "Hotel California", "duration": "6:30"},
{"title": "Stairway to Heaven", "duration": "8:02"},
{"title": "Imagine", "duration": "3:07"},
{"title": "Smells Like Teen Spirit", "duration": "5:01"},
{"title": "Billie Jean", "duration": "4:54"},
{"title": "Hey Jude", "duration": "7:11"},
{"title": "Like a Rolling Stone", "duration": "6:13"},
]

# %% [markdown]
# Calcule la duración total de la playlist en formato Xm Ys, y encuentre la
# canción más larga y la más corta.
# Nota: Deberá convertir las duraciones de string a valores
# numéricos para poder operar con ellas.

# %% [markdown]
# Salida esperada:
# Duración total: 46m 53s
# Canción más larga: "Stairway to Heaven" (8:02)
# Canción más corta: "Imagine" (3:07)

# %% [markdown]
# Declaro las variables

# %%
total_segundos = 0
cancion_mas_larga = None
cancion_mas_corta = None
segundos_maximos = 0
segundos_minimos = 9999

# %%
for cancion in playlist:
    minutos, segundos = cancion["duration"].split(":")
    duracion_seg = int(minutos) * 60 + int(segundos)
    total_segundos += duracion_seg
    if duracion_seg > segundos_maximos:
        cancion_mas_larga = cancion
        segundos_maximos = duracion_seg
    
    if duracion_seg < segundos_minimos:
        cancion_mas_corta = cancion
        segundos_minimos = duracion_seg

# convertir total a minutos y segundos
total_min = total_segundos // 60
total_seg = total_segundos % 60

# %%
print(f"Duración total: {total_min} m {total_seg} s")
print(f"Canción más larga: {cancion_mas_larga['title']} {cancion_mas_larga['duration']}")
print(f"Canción más corta: {cancion_mas_corta['title']} {cancion_mas_corta['duration']}")
# Out:
# Duración total: 46 m 53 s
# Canción más larga: Stairway to Heaven 8:02
# Canción más corta: Imagine 3:07
