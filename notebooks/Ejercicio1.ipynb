# %% [markdown]
# Ejercicio 1
# Dado el siguiente texto almacenado en una variable, calcule e imprima:
# La cantidad total de líneas.
# La cantidad total de palabras.
# El promedio de palabras por línea.
# Todas las líneas cuya cantidad de palabras esté por encima del promedio.

# %%
text = """Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way
to do it.
Although that way may not be obvious at first unless you're
Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good
idea.
Namespaces are one honking great idea -- let's do more of those!"""

# %% [markdown]
# Primero importo las funciones que están en la carpeta `src`, donde se encuentra la lógica del programa. Agrego esa carpeta al path del sistema para poder importar los módulos desde el notebook. Además utilizo `importlib.reload()` para recargar el módulo cada vez que modifico las funciones, ya que Jupyter guarda los módulos en memoria y no actualiza los cambios automáticamente.

# %%
import sys
sys.path.append("../src")
import importlib
import funciones_texto as ft
importlib.reload(ft)
# Out:
# <module 'funciones_texto' from 'c:\\users\\Estudio\\seminario.python\\proyecto2026\\notebooks\\../src\\funciones_texto.py'>

# %% [markdown]
# Invoco la funcion para el calculo de la cantidad de lineas del texto

# %%
print(f"total de lineas: ", ft.contar_lineas(text))
# Out:
# total de lineas:  19

# %% [markdown]
# Funcion para contar la cantidad de palabras de un texto

# %%
print (f"Total de palabras: ", ft.contar_palabras(text))
# Out:
# Total de palabras:  137

# %% [markdown]
# Esta fucnion divide cada linea y me genera una lista con la cantidad de palabras dentro de esa oracion.

# %%
ft.palabras_por_linea(text)
# Out:
# [5, 5, 5, 5, 5, 5, 2, 9, 4, 5, 3, 10, 13, 12, 5, 8, 11, 13, 12]

# %% [markdown]
# Esta funcion me devuelve las oraciones mayores al promedio, dentro del texto.

# %%
ft.linea_sobre_promedio(text)
# Out:
# ["\nSpecial cases aren't special enough to break the rules",
#  '\nIn the face of ambiguity, refuse the temptation to guess',
#  '\nThere should be one-- and preferably only one --obvious way\nto do it',
#  "\nAlthough that way may not be obvious at first unless you're\nDutch",
#  '\nAlthough never is often better than *right* now',
#  "\nIf the implementation is hard to explain, it's a bad idea",
#  '\nIf the implementation is easy to explain, it may be a good\nidea',
#  "\nNamespaces are one honking great idea -- let's do more of those!"]
